# %% [markdown]
# # SISTEMAS DE RECOMENDACIÓN 2
# ## PRÁCTICA

# %% [markdown]
# <img src="portada.jpg" align="center" width="80%"/>

# %% [markdown]
# El principal objetivo de cualquier sistema de recomendación es ofrecer a los usuarios una experiencia personalizada. ¿Cómo traducimos esto a un problema de machine learning? Tenemos dos tipos de problemas:
#
# - Problema de predicción: el primer enfoque es aquel en el que nos gustaría predecir el valor de calificación de una combinación usuario-artículo con la suposición de que se dispone de datos de entrenamiento que indican la preferencia de un usuario por otros artículos. Imaginemos una matriz m × n, donde m es el número de usuarios y n el número de elementos, y el objetivo es predecir los valores que faltan (o no observados).
# <br>
#
# - Problema de clasificación: en otras ocasiones, deseamos recomendar los k mejores artículos para un usuario concreto o determinar los k mejores usuarios a los que dirigirnos para un tema específico. Este problema también se denomina problema de recomendación top-k y es la formulación de clasificación del problema de recomendación. Pensemos en un motor de búsqueda en el que, en función de quién realice la búsqueda, nos gustaría mostrar los elementos top-k para ofrecer resultados personalizados basados en sus preferencias anteriores y en su actividad reciente.

# %% [markdown]
# Clasficación de sistemas de recomendación
#
# <img src="sintesis.jpg" align="center" width="60%"/>

# %%
# %pip install chart_studio
# %pip install datapane
# %pip install pip install scikit-surprise
# %pip install --upgrade pandas

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datapane as dp
import chart_studio.plotly as py
import chart_studio
import os

from sklearn.model_selection import train_test_split as skl_train_test_split
from surprise import KNNBasic,NormalPredictor,BaselineOnly,NMF

# username = os.environ['PLOTLY_USERNAME']
# api_key = os.environ['PLOTLY_API_KEY']
# chart_studio.tools.set_credentials_file(username=username, api_key=api_key)
# %matplotlib inline

# %% [markdown]
# Utilizamos el dataset goodbooks-10k (disponible en Kaggle). El primer CSV contiene datos de 10k libros puntuados por 53k usuarios. El segundo CSV contiene los metadatos (título, autor, ISBN, etc) para cada uno de los 10k libros.

# %%
ratings_data = pd.read_csv('./data/books/ratings.csv.zip')
books_metadata = pd.read_csv('./data/books/books.csv.zip')
ratings_data.head(10)
# Out:
#    book_id  user_id  rating
# 0        1      314       5
# 1        1      439       3
# 2        1      588       5
# 3        1     1169       4
# 4        1     1185       4
# 5        1     2077       4
# 6        1     2487       4
# 7        1     2900       5
# 8        1     3662       4
# 9        1     3922       5

# %%
ratings_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 981756 entries, 0 to 981755
# Data columns (total 3 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   book_id  981756 non-null  int64
#  1   user_id  981756 non-null  int64
#  2   rating   981756 non-null  int64
# dtypes: int64(3)
# memory usage: 22.5 MB

# %%
books_metadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 23 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         10000 non-null  int64
#  1   book_id                    10000 non-null  int64
#  2   best_book_id               10000 non-null  int64
#  3   work_id                    10000 non-null  int64
#  4   books_count                10000 non-null  int64
#  5   isbn                       9300 non-null   object
#  6   isbn13                     9415 non-null   float64
#  7   authors                    10000 non-null  object
#  8   original_publication_year  9979 non-null   float64
#  9   original_title             9415 non-null   object
#  10  title                      10000 non-null  object
#  11  language_code              8916 non-null   object
#  12  average_rating             10000 non-null  float64
#  13  ratings_count              10000 non-null  int64
#  14  work_ratings_count         10000 non-null  int64
#  15  work_text_reviews_count    10000 non-null  int64
#  16  ratings_1                  10000 non-null  int64
#  17  ratings_2                  10000 non-null  int64
#  18  ratings_3                  10000 non-null  int64
#  19  ratings_4                  10000 non-null  int64
#  20  ratings_5                  10000 non-null  int64
#  21  image_url                  10000 non-null  object
#  22  small_image_url            10000 non-null  object
# dtypes: float64(3), int64(13), object(7)
# memory usage: 1.8+ MB

# %% [markdown]
# Tenemos además un dataset de tags, que nos da detalles sobre el argumento del libro.

# %%
book_tags = pd.read_csv('./data/books/book_tags.csv')
tags = pd.read_csv('./data/books/tags.csv')

# %%
data = pd.merge(book_tags, tags, left_on='tag_id', right_on='tag_id', how='inner')
titles = books_metadata[['id', 'book_id','title','authors']]
data = pd.merge(titles, data, left_on='book_id', right_on='goodreads_book_id')
data.drop(['goodreads_book_id', 'tag_id', 'count'], axis=1,inplace=True)
data.head(3)
# Out:
#    id  book_id                                    title          authors  \
# 0   1  2767052  The Hunger Games (The Hunger Games, #1)  Suzanne Collins
# 1   1  2767052  The Hunger Games (The Hunger Games, #1)  Suzanne Collins
# 2   1  2767052  The Hunger Games (The Hunger Games, #1)  Suzanne Collins
#
#     tag_name
# 0    to-read
# 1    fantasy
# 2  favorites

# %%
list_tags = data.groupby(by='book_id')['tag_name'].apply(set).apply(list)
books_metadata['tags'] = books_metadata['book_id'].apply(lambda x: ' '.join(list_tags[x]))
pd.reset_option('max_colwidth')
books_metadata.head(3)
# Out:
#    id  book_id  best_book_id  work_id  books_count       isbn        isbn13  \
# 0   1  2767052       2767052  2792775          272  439023483  9.780439e+12
# 1   2        3             3  4640799          491  439554934  9.780440e+12
# 2   3    41865         41865  3212258          226  316015849  9.780316e+12
#
#                        authors  original_publication_year  \
# 0              Suzanne Collins                     2008.0
# 1  J.K. Rowling, Mary GrandPré                     1997.0
# 2              Stephenie Meyer                     2005.0
#
#                              original_title  ... work_ratings_count  \
# 0                          The Hunger Games  ...            4942365
# 1  Harry Potter and the Philosopher's Stone  ...            4800065
# 2                                  Twilight  ...            3916824
#
#   work_text_reviews_count  ratings_1  ratings_2  ratings_3  ratings_4  \
# 0                  155254      66715     127936     560092    1481305
# 1                   75867      75504     101676     455024    1156318
# 2                   95009     456191     436802     793319     875073
#
#    ratings_5                                          image_url  \
# 0    2706317  https://images.gr-assets.com/books/1447303603m...
# 1    3011543  https://images.gr-assets.com/books/1474154022m...
# 2    1355439  https://images.gr-assets.com/books/1361039443m...
#
#                                      small_image_url  \
# 0  https://images.gr-assets.com/books/1447303603s...
# 1  https://images.gr-assets.com/books/1474154022s...
# 2  https://images.gr-assets.com/books/1361039443s...
#
#                                                 tags
# 0  books teen-fiction loved adventure suzanne-col...
# 1  books read-2016 england adventure childrens-bo...
# 2  meh books teen-fiction movies young-adults twi...
#
# [3 rows x 24 columns]

# %%
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel

# %% [markdown]
# Al trabajar con texto, podemos aplicar una transformación llamada **TF-IDF**, o Term Frequency-Inverse Document Frecuency.
#
# El **número de features** que crea es igual al número total de palabras distintas utilizadas en la columna de tags.
#
# Los **valores** son directamente *proporcionales al número de veces que se utiliza una palabra concreta* e *inversamente proporcionales al número de documentos (películas en este caso) en los que se utiliza la palabra*.
#
# Penalizará una palabra presente en los tags de un libro si es común a muchos libros. Las palabras que aparecen varias veces pero son comunes a muchos libros no son tan útiles para diferenciar los distintas libros.
#
# En otras palabras, **el proceso TF-IDF nos dice que tan relevante es una palabra a un documento, en una colección de documentos**.

# %% [markdown]
# t - término (palabra) <br>
# d - documento (conjunto de palabras) <br>
# N - cantidad de documentos
# <br>
#
# tf(t,d) = cantidad de t in d / cantidad de palabras en d
#
# df(t) = ocurrencia de t en N documentos
#
# idf(t) = N/df
#
# IDF es la inversa de la frecuencia de documentos que mide que tan informativo es el término t. Cuando calculamos IDF, será muy bajo para las palabras más frecuentes, como las stop words (porque están presentes en casi todos los documentos, y N/df dará un valor muy bajo a esa palabra). Esto da finalmente lo que queremos, un peso relativo.
#
# Se suele usar el logaritmo para contrarrestar el efecto de un N muy grande: idf(t) = log(N/(df + 1)).
#
# El score final será la multiplicación de ambos términos:
#
# **tf-idf(t, d) = tf(t, d) * log(N/(df + 1))**

# %%
tfidf = TfidfVectorizer(stop_words='english')

tags_matrix = tfidf.fit_transform(books_metadata['tags'])

tags_matrix.shape
# Out:
# (10000, 16396)

# %%
#Cantidad de veces que se repite cada término
tfidf.vocabulary_
# Out:
# {'books': 2075,
#  'teen': 13848,
#  'fiction': 5289,
#  'loved': 8573,
#  'adventure': 641,
#  'suzanne': 13620,
#  'collins': 3179,
#  'fantasy': 5132,
#  'sci': 12468,
#  'fi': 5268,
#  'read': 11635,
#  'owned': 10424,
#  'science': 12470,
#  'finished': 5358,
#  'series': 12640,
#  'hunger': 6863,
#  'games': 5744,
#  '2012': 253,
#  'default': 3899,
#  'dystopian': 4451,
#  '2014': 255,
#  'ebook': 4487,
#  'novel': 10105,
#  'favorite': 5188,
#  'audiobooks': 1336,
#  'ya': 15260,
#  'futuristic': 5688,
#  'favs': 5199,
#  'favourites': 5197,
#  'love': 8570,
#  'triangle': 14275,
#  'survival': 13600,
#  'scifi': 12480,
#  'thriller': 14012,
#  'favorites': 5190,
#  'reviewed': 11939,
#  'borrowed': 2112,
#  'young': 15308,
#  'adult': 632,
#  'action': 563,
#  'novels': 10119,
#  'audiobook': 1334,
#  'kindle': 7818,
#  'reads': 11662,
#  'completed': 3269,
#  'book': 2049,
#  'coming': 3228,
#  'age': 686,
#  'trilogy': 14289,
#  'distopian': 4180,
#  '2011': 251,
#  '2013': 254,
#  'favourite': 5196,
#  'suspense': 13612,
#  'audio': 1333,
#  'buy': 2418,
#  'dystopia': 4450,
#  'library': 8325,
#  'club': 3089,
#  'contemporary': 3375,
#  'post': 11099,
#  'apocalyptic': 1068,
#  'sf': 12671,
#  'time': 14053,
#  'dystopias': 4453,
#  'ebooks': 4490,
#  'shelfari': 12754,
#  'star': 13315,
#  'reread': 11889,
#  'currently': 3705,
#  'reading': 11658,
#  'speculative': 13198,
#  'faves': 5182,
#  'distopia': 4179,
#  'lit': 8426,
#  'future': 5686,
#  'english': 4736,
#  'drama': 4328,
#  '2010': 249,
#  'stars': 13324,
#  'romance': 12101,
#  '2016': 257,
#  'england': 4733,
#  'childrens': 2884,
#  'harry': 6375,
#  'potter': 11121,
#  'children': 2883,
#  'jk': 7461,
#  'rowling': 12168,
#  '2015': 256,
#  'childhood': 2877,
#  'kids': 7780,
#  'bookshelf': 2082,
#  'shelf': 12752,
#  'classics': 3027,
#  'witches': 15109,
#  'middle': 9272,
#  'grade': 6068,
#  'friendship': 5633,
#  'literature': 8435,
#  'supernatural': 13575,
#  'wizards': 15119,
#  'rereads': 11892,
#  'magic': 8724,
#  'paranormal': 10526,
#  'mystery': 9709,
#  'juvenile': 7594,
#  'urban': 14547,
#  'british': 2277,
#  'classic': 3020,
#  'youth': 15314,
#  '2017': 259,
#  'meh': 9129,
#  'movies': 9588,
#  'adults': 636,
#  'twilight': 14391,
#  'saga': 12280,
#  '2009': 246,
#  'movie': 9586,
#  'stephenie': 13369,
#  'meyer': 9232,
#  'werewolves': 14964,
#  'vampires': 14604,
#  'romantic': 12113,
#  'chick': 2857,
#  'horror': 6766,
#  'american': 879,
#  'youngadult': 15310,
#  'vampire': 14603,
#  '2008': 244,
#  'did': 4087,
#  'finish': 5356,
#  'séries': 13689,
#  'guilty': 6211,
#  'pleasures': 10950,
#  'pleasure': 10949,
#  'stephanie': 13365,
#  'pnr': 10964,
#  'vamps': 14607,
#  'high': 6565,
#  'school': 12458,
#  'abandoned': 472,
#  'dnf': 4213,
#  '1001': 42,
#  'general': 5828,
#  'usa': 14559,
#  'pulitzer': 11411,
#  'prize': 11256,
#  'banned': 1540,
#  'clàssics': 3094,
#  'die': 4092,
#  'racism': 11532,
#  'historical': 6623,
#  '20th': 274,
#  'century': 2717,
#  'modern': 9437,
#  'wish': 15097,
#  'list': 8418,
#  'required': 11887,
#  'literary': 8431,
#  'harper': 6366,
#  'lee': 8188,
#  'history': 6638,
#  'realistic': 11676,
#  'family': 5095,
#  'crime': 3594,
#  'rory': 12141,
#  'gilmore': 5933,
#  'challenge': 2739,
#  'southern': 13165,
#  'bookclub': 2056,
#  'race': 11524,
#  'stand': 13305,
#  'scott': 12495,
#  'fitzgerald': 5396,
#  'america': 878,
#  'new': 9920,
#  'york': 15302,
#  '1920s': 151,
#  'signed': 12887,
#  'funny': 5679,
#  'john': 7487,
#  'green': 6125,
#  'want': 14849,
#  'death': 3860,
#  'emotional': 4675,
#  'story': 13421,
#  'cancer': 2503,
#  'sad': 12269,
#  'cried': 3593,
#  'illness': 6959,
#  'tear': 13821,
#  'jerker': 7426,
#  'jerkers': 7427,
#  'humor': 6855,
#  'fault': 5176,
#  'audible': 1331,
#  'tolkien': 14118,
#  'earth': 4469,
#  'hold': 6688,
#  'epic': 4791,
#  'personal': 10725,
#  'unfinished': 14479,
#  'jrr': 7539,
#  'dragons': 4327,
#  'lord': 8542,
#  'rings': 12004,
#  'bildungsroman': 1843,
#  'salinger': 12311,
#  '1950s': 170,
#  'murder': 9635,
#  'religion': 11821,
#  'paperback': 10510,
#  'italy': 7304,
#  'religious': 11825,
#  'conspiracy': 3341,
#  'thrillers': 14015,
#  '2006': 242,
#  'روايات': 15957,
#  'home': 6714,
#  'robert': 12059,
#  'langdon': 8075,
#  'brown': 2311,
#  'dan': 3768,
#  'art': 1181,
#  'detective': 4015,
#  '2005': 241,
#  'mysteries': 9706,
#  'mistery': 9387,
#  'popular': 11057,
#  '19th': 214,
#  'brit': 2273,
#  'tbr': 13804,
#  'regency': 11767,
#  'nook': 10049,
#  'austen': 1359,
#  'women': 15144,
#  'jane': 7351,
#  'islam': 7276,
#  'group': 6164,
#  'east': 4473,
#  '21st': 278,
#  'afghanistan': 668,
#  'contempor': 3368,
#  'ary': 1216,
#  'war': 14854,
#  'recommended': 11717,
#  'asia': 1235,
#  'international': 7185,
#  'culture': 3685,
#  'cultural': 3683,
#  'khaled': 7751,
#  'hosseini': 6784,
#  'non': 10031,
#  'multicultural': 9614,
#  'veronica': 14663,
#  'roth': 12155,
#  'divergent': 4189,
#  'political': 11019,
#  'satire': 12389,
#  'politics': 11021,
#  'ｆａｖｏｒｉｔｅｓ': 16392,
#  'social': 13070,
#  'commentary': 3236,
#  'philosophy': 10791,
#  'george': 5866,
#  'orwell': 10366,
#  'allegory': 817,
#  'animals': 987,
#  'communism': 3248,
#  'novella': 10116,
#  'bio': 1862,
#  'memoir': 9155,
#  'biographical': 1877,
#  'biography': 1881,
#  'diary': 4072,
#  'anne': 1000,
#  'frank': 5572,
#  'nonfiction': 10040,
#  'autobiography': 1386,
#  'female': 5228,
#  'authors': 1375,
#  'dutch': 4428,
#  'ww2': 15226,
#  'europe': 4931,
#  'netherlands': 9898,
#  'translated': 14237,
#  'wwii': 15229,
#  'true': 14316,
#  'holocaust': 6711,
#  'diaries': 4071,
#  'autobiographies': 1385,
#  'memoirs': 9157,
#  'world': 15178,
#  'ii': 6942,
#  'biographies': 1880,
#  'auto': 1379,
#  'inspirational': 7134,
#  'german': 5877,
#  'germany': 5880,
#  'jewish': 7443,
#  'couldn': 3483,
#  'gave': 5788,
#  'millennium': 9314,
#  'dark': 3800,
#  'abuse': 527,
#  'swedish': 13641,
#  'translation': 14238,
#  'scandinavian': 12420,
#  'scandinavia': 12419,
#  'didn': 4090,
#  'sweden': 13640,
#  'stieg': 13386,
#  'larsson': 8094,
#  'travel': 14251,
#  'lotr': 8559,
#  'fantasía': 5137,
#  'fantasia': 5122,
#  'elves': 4654,
#  'magical': 8725,
#  'hp': 6813,
#  'multiple': 9618,
#  'times': 14059,
#  'author': 1374,
#  '2003': 239,
#  'boarding': 1996,
#  'grief': 6143,
#  'realism': 11674,
#  'ghosts': 5899,
#  'rape': 11591,
#  'afterlife': 679,
#  'alice': 799,
#  'sebold': 12541,
#  '2004': 240,
#  'france': 5555,
#  'psychology': 11382,
#  '9th': 432,
#  'tragedy': 14209,
#  'romeo': 12125,
#  'juliet': 7563,
#  'teatro': 13828,
#  'assigned': 1262,
#  'renaissance': 11844,
#  'poetry': 10985,
#  'william': 15051,
#  'shakespeare': 12694,
#  'stories': 13415,
#  'plays': 10942,
#  'theater': 13944,
#  'theatre': 13946,
#  'play': 10937,
#  '16th': 101,
#  'psychological': 11378,
#  'listened': 8422,
#  'fun': 5669,
#  'sociopath': 13080,
#  'bought': 2130,
#  'summer': 13556,
#  'creepy': 3581,
#  'gillian': 5930,
#  'flynn': 5453,
#  'gone': 6018,
#  'girl': 5938,
#  'marriage': 8914,
#  'maybe': 9017,
#  'mental': 9174,
#  'purchased': 11427,
#  'recommend': 11714,
#  'dysfunctional': 4447,
#  'mississippi': 9378,
#  'racial': 11529,
#  'discrimination': 4156,
#  'african': 674,
#  'segregation': 12562,
#  'help': 6488,
#  '1960s': 176,
#  'civil': 2987,
#  'rights': 11997,
#  'maids': 8748,
#  'kathryn': 7660,
#  'stockett': 13392,
#  'nobel': 10017,
#  '1930s': 154,
#  'novellas': 10117,
#  'steinbeck': 13355,
#  'americana': 880,
#  'california': 2468,
#  'asian': 1236,
#  'japan': 7362,
#  'historic': 6621,
#  'geisha': 5810,
#  'japanese': 7363,
#  'erotic': 4842,
#  'hot': 6790,
#  'alpha': 838,
#  'males': 8780,
#  'virgin': 14741,
#  'heroine': 6524,
#  'dropped': 4366,
#  'bdsm': 1634,
#  'chicklit': 2860,
#  'waste': 14881,
#  'nope': 10055,
#  'sexy': 12668,
#  'shades': 12683,
#  'grey': 6140,
#  'chic': 2852,
#  'erótica': 4850,
#  'erotica': 4843,
#  'james': 7344,
#  'wtf': 15219,
#  'male': 8779,
#  'steamy': 13348,
#  'billionaire': 1851,
#  'college': 3176,
#  'boyfriends': 2165,
#  'sex': 12661,
#  '50': 360,
#  'spirituality': 13232,
#  'brazil': 2216,
#  'development': 4031,
#  'life': 8351,
#  'brazilian': 2217,
#  'coelho': 3130,
#  'paulo': 10603,
#  'alchemist': 767,
#  'spiritual': 13228,
#  'self': 12578,
#  'improvement': 7010,
#  'latin': 8108,
#  'africa': 673,
#  'spain': 13177,
#  'motivational': 9566,
#  'inspiring': 7139,
#  'philosophical': 10789,
#  'fable': 5048,
#  'inspiration': 7133,
#  'need': 9852,
#  'unlimited': 14506,
#  'kid': 7766,
#  'chapter': 2774,
#  'award': 1426,
#  'winner': 15076,
#  'thought': 14001,
#  'provoking': 11338,
#  'grades': 6073,
#  'newberry': 9923,
#  'winners': 15077,
#  'cs': 3666,
#  'lewis': 8285,
#  'christian': 2930,
#  'chronicles': 2950,
#  'narnia': 9776,
#  'alouds': 836,
#  'aloud': 835,
#  'christianity': 2936,
#  'chicago': 2854,
#  'audrey': 1340,
#  'niffenegger': 9966,
#  'song': 13110,
#  'ice': 6911,
#  'martin': 8927,
#  'game': 5743,
#  'thrones': 14019,
#  'rr': 12178,
#  'asoiaf': 1245,
#  'medieval': 9112,
#  'stopped': 13408,
#  'food': 5473,
#  'yoga': 15297,
#  'elizabeth': 4635,
#  'gilbert': 5926,
#  'writing': 15212,
#  'india': 7041,
#  'indonesia': 7058,
#  'percy': 10690,
#  'jackson': 7326,
#  'olympians': 10261,
#  'gods': 6000,
#  'rick': 11982,
#  'riordan': 12006,
#  'mythology': 9719,
#  'greek': 6123,
#  'louisa': 8567,
#  'alcott': 776,
#  'sisters': 12941,
#  'gothic': 6054,
#  'feminism': 5233,
#  'charlotte': 2792,
#  'bronte': 2294,
#  'uk': 14425,
#  'victorian': 14698,
#  'writers': 15211,
#  'saw': 12403,
#  'fluff': 5445,
#  'notebook': 10087,
#  'nicholas': 9950,
#  'sparks': 13184,
#  'seen': 12559,
#  'womens': 15145,
#  'relationships': 11802,
#  'man': 8798,
#  'booker': 2061,
#  'canadian': 2496,
#  'canada': 2495,
#  'depression': 3974,
#  'era': 4817,
#  'great': 6117,
#  'aging': 700,
#  'circus': 2979,
#  'sara': 12369,
#  'gruen': 6178,
#  'selections': 12574,
#  'elephants': 4615,
#  'favouri': 5194,
#  'tes': 13913,
#  'australian': 1367,
#  'ray': 11622,
#  'bradbury': 2180,
#  'censorship': 2711,
#  'utopia': 14571,
#  'shapeshifters': 12719,
#  'shifters': 12788,
#  'werewolf': 14962,
#  'elementary': 4610,
#  'comedy': 3213,
#  'picture': 10841,
#  'kiddos': 7772,
#  'memories': 9161,
#  'humour': 6859,
#  'stuff': 13487,
#  'illustrated': 6963,
#  'short': 12825,
#  'nostalgia': 10082,
#  'readers': 11655,
#  'child': 2871,
#  '100': 38,
#  'lifetime': 8356,
#  'poems': 10974,
#  'childrensbooks': 2886,
#  'shel': 12749,
#  'silverstein': 12901,
#  'mortal': 9547,
#  'instruments': 7153,
#  'angels': 964,
#  'demons': 3953,
#  'shadowhunters': 12686,
#  'cassandra': 2618,
#  'clare': 3008,
#  'lgbt': 8294,
#  'faeries': 5064,
#  'dragon': 4322,
#  'inheritance': 7103,
#  'christopher': 2946,
#  'paolini': 10504,
#  'cycle': 3727,
#  'eragon': 4818,
#  'aliens': 803,
#  'space': 13173,
#  'humorous': 6858,
#  'fantascienza': 5120,
#  'douglas': 4297,
#  'adams': 581,
#  'hilarious': 6579,
#  '1970s': 182,
#  'aldous': 777,
#  'huxley': 6884,
#  'teens': 13853,
#  'pregnancy': 11177,
#  'hardcover': 6344,
#  'breaking': 2223,
#  'dawn': 3833,
#  'sagas': 12283,
#  'sue': 13533,
#  'monk': 9490,
#  'kidd': 7768,
#  'strong': 13464,
#  'south': 13163,
#  'bees': 1682,
#  'mark': 8892,
#  'twain': 14380,
#  'slavery': 13000,
#  'girls': 5943,
#  'ap': 1059,
#  'newbery': 9924,
#  'honor': 6738,
#  'white': 15002,
#  'animal': 985,
#  'autism': 1378,
#  'spectrum': 13197,
#  'disability': 4133,
#  '420': 347,
#  'narrativa': 9779,
#  'special': 13192,
#  'needs': 9854,
#  'misc': 9364,
#  'alex': 787,
#  'good': 6021,
#  'aspergers': 1248,
#  'health': 6438,
#  'selection': 12573,
#  'teaching': 13815,
#  '8th': 418,
#  'asperger': 1247,
#  'syndrome': 13677,
#  'bookgroup': 2064,
#  'paula': 10600,
#  'hawkins': 6414,
#  'unreliable': 14519,
#  'narrator': 9782,
#  'alcoholism': 774,
#  'adultery': 633,
#  'steampunk': 13346,
#  'materials': 8970,
#  'philip': 10774,
#  'pullman': 11414,
#  'emily': 4670,
#  'classici': 3023,
#  'ethics': 4915,
#  'picoult': 10838,
#  'medical': 9108,
#  'alones': 834,
#  'dying': 4440,
#  'jodi': 7476,
#  'postmodern': 11109,
#  'vonnegut': 14784,
#  'kurt': 8004,
#  'georgia': 5869,
#  'margaret': 8865,
#  'mitchell': 9395,
#  'wind': 15066,
#  'bbc': 1625,
#  'big': 1831,
#  'adolescence': 614,
#  'lgbtq': 8295,
#  'lgbtqia': 8298,
#  'favoritos': 5191,
#  'epistolary': 4804,
#  'orson': 10361,
#  'card': 2550,
#  'military': 9306,
#  'sciencefiction': 12472,
#  'hugo': 6836,
#  'opera': 10303,
#  'ender': 4709,
#  'uni': 14484,
#  'romanticism': 12116,
#  'university': 14501,
#  'monsters': 9500,
#  'scary': 12435,
#  'spooky': 13247,
#  'ghost': 5896,
#  'king': 7824,
#  'stephen': 13367,
#  'alien': 800,
#  'host': 6785,
#  'printz': 11242,
#  'standalone': 13306,
#  'pov': 11129,
#  'light': 8358,
#  '1990s': 204,
#  'girly': 5944,
#  'húmor': 6899,
#  'just': 7587,
#  'london': 8518,
#  'beach': 1636,
#  'helen': 6477,
#  'fielding': 5300,
#  '1800s': 117,
#  'medal': 9103,
#  'classroom': 3033,
#  'holes': 6693,
#  'boys': 2169,
#  'watched': 14885,
#  'nyc': 10153,
#  'lauren': 8133,
#  'weisberger': 14944,
#  'fashion': 5161,
#  'homer': 6719,
#  'ancient': 937,
#  'greece': 6121,
#  'classical': 3021,
#  'studies': 13480,
#  'epics': 4793,
#  'myth': 9714,
#  'antiquity': 1042,
#  'francais': 5553,
#  'french': 5617,
#  'fairy': 5074,
#  'tales': 13731,
#  'clásicos': 3096,
#  'français': 5585,
#  'fic': 5274,
#  'families': 5094,
#  'homelessness': 6717,
#  'poverty': 11130,
#  'appalachia': 1078,
#  'outdoors': 10393,
#  'wilderness': 15036,
#  'exploration': 5013,
#  'journalism': 7528,
#  'environment': 4779,
#  'jon': 7500,
#  'krakauer': 7962,
#  'nature': 9812,
#  'alaska': 755,
#  'wanderlust': 14845,
#  'dickens': 4080,
#  'paris': 10541,
#  'revolution': 11943,
#  'charles': 2787,
#  'jurassic': 7582,
#  'park': 10542,
#  'michael': 9251,
#  'crichton': 3591,
#  'cloning': 3079,
#  'techno': 13837,
#  'dinosaurs': 4119,
#  'giving': 5951,
#  'tree': 14265,
#  'edrd': 4544,
#  '314': 315,
#  'picturebooks': 10845,
#  'calibre': 2464,
#  'lawyers': 8144,
#  'legal': 8193,
#  'grisham': 6154,
#  'law': 8139,
#  'revenge': 11935,
#  'trials': 14274,
#  'courtroom': 3513,
#  'night': 9970,
#  'oprah': 10313,
#  'genocide': 5844,
#  'elie': 4623,
#  'wiesel': 15025,
#  'judaism': 7545,
#  'standalones': 13307,
#  'paper': 10508,
#  'towns': 14183,
#  'road': 12045,
#  'trip': 14296,
#  'tale': 13726,
#  'fairytales': 5079,
#  'sword': 13659,
#  'laser': 8096,
#  'goldman': 6010,
#  'genre': 5848,
#  '40': 341,
#  'outsiders': 10402,
#  'gangs': 5749,
#  'maze': 9027,
#  'runner': 12205,
#  'dashner': 3816,
#  'economics': 4509,
#  'business': 2408,
#  'academic': 533,
#  'finance': 5345,
#  'econ': 4505,
#  'economic': 4508,
#  'statistics': 13338,
#  'behavioral': 1692,
#  'management': 8799,
#  'education': 4552,
#  'interesting': 7178,
#  'current': 3704,
#  'affairs': 664,
#  'nonfic': 10037,
#  'money': 9484,
#  'sciences': 12473,
#  'sociology': 13079,
#  'reference': 11750,
#  'educational': 4553,
#  'economy': 4512,
#  'pop': 11048,
#  'events': 4946,
#  'society': 13074,
#  'essays': 4897,
#  'mathematics': 8975,
#  'frances': 5556,
#  'hodgson': 6679,
#  'burnett': 2395,
#  'spanish': 13178,
#  'colombian': 3183,
#  'gabriel': 5712,
#  'garcia': 5758,
#  'marquez': 8910,
#  'colombia': 3182,
#  'español': 4877,
#  'ireland': 7246,
#  'oscar': 10370,
#  'wilde': 15034,
#  'queer': 11480,
#  'irish': 7249,
#  'smut': 13042,
#  'el': 4590,
#  'bram': 2194,
#  'stoker': 13398,
#  'terror': 13907,
#  'dracula': 4320,
#  'nordic': 10062,
#  'noir': 10024,
#  'computer': 3283,
#  'hacker': 6252,
#  'bestsellers': 1776,
#  'lisbeth': 8413,
#  'salander': 12307,
#  'angsty': 981,
#  'boyfriend': 2164,
#  'kobo': 7915,
#  'bad': 1484,
#  'boy': 2161,
#  'mf': 9236,
#  'intense': 7165,
#  'naughty': 9814,
#  'hero': 6519,
#  'annoying': 1009,
#  'interested': 7177,
#  'leidos': 8205,
#  'erotik': 4844,
#  'fanfiction': 5108,
#  'boring': 2108,
#  'fav': 5178,
#  'pdf': 10622,
#  'trilogies': 14288,
#  'billionaires': 1852,
#  'oprahs': 10315,
#  'congo': 3309,
#  'colonialism': 3187,
#  'barbara': 1554,
#  'kingsolver': 7834,
#  'missionaries': 9375,
#  'gay': 5793,
#  'david': 3828,
#  'sedaris': 12552,
#  'essay': 4896,
#  'glbt': 5962,
#  '2000s': 236,
#  'lol': 8513,
#  'caldecott': 2457,
#  'maurice': 9006,
#  'sendak': 12601,
#  'storytime': 13426,
#  'preschool': 11193,
#  'imagination': 6980,
#  'alexandre': 790,
#  'dumas': 4404,
#  'apocalypse': 1066,
#  'mccarthy': 9046,
#  'end': 4703,
#  'cormac': 3448,
#  'pulitzers': 11412,
#  'disappointing': 4138,
#  'feminist': 5237,
#  'tina': 14065,
#  'fey': 5260,
#  'celebrity': 2696,
#  'bios': 1890,
#  'television': 13869,
#  'tearjerkers': 13824,
#  'tearjerker': 13823,
#  'nicolas': 9957,
#  'shopaholic': 12821,
#  'kinsella': 7840,
#  'shopping': 12823,
#  'sophie': 13128,
#  'chiclit': 2864,
#  'brain': 2185,
#  'candy': 2510,
#  'victor': 14696,
#  'kim': 7800,
#  'edwards': 4556,
#  'downs': 4311,
#  'picks': 10834,
#  'secrets': 12548,
#  'disabilities': 4132,
#  'twins': 14393,
#  'adoption': 621,
#  'heartbreaking': 6448,
#  'assisted': 1266,
#  'suicide': 13548,
#  'ugly': 14422,
#  'jojo': 7496,
#  'moyes': 9591,
#  'mitch': 9393,
#  'albom': 763,
#  'lessons': 8259,
#  'sexuality': 12666,
#  'detroit': 4022,
#  'hermaphrodite': 6516,
#  'gender': 5824,
#  'michigan': 9258,
#  'missouri': 9380,
#  'immigration': 6988,
#  'amy': 909,
#  'tan': 13751,
#  'chinese': 2901,
#  'immigrant': 6986,
#  'experience': 5005,
#  'mothers': 9561,
#  'daughters': 3823,
#  'china': 2898,
#  'shared': 12723,
#  'atwood': 1325,
#  'sisterhood': 12940,
#  'traveling': 14253,
#  'pants': 10503,
#  'ann': 997,
#  'brashares': 2202,
#  'ýa': 15448,
#  'vladimir': 14766,
#  'nabokov': 9737,
#  'russian': 12226,
#  'controversial': 3399,
#  'disturbing': 4184,
#  'gregory': 6135,
#  'maguire': 8734,
#  'fairytale': 5078,
#  'oz': 10432,
#  'wizard': 15117,
#  'retellings': 11919,
#  'retelling': 11918,
#  'wicked': 15013,
#  'lawyer': 8143,
#  'organized': 10342,
#  'government': 6057,
#  'memphis': 9163,
#  'investigators': 7223,
#  'firms': 5379,
#  'emma': 4672,
#  'donoghue': 4266,
#  'captivity': 2540,
#  'abduction': 486,
#  'kidnapping': 7778,
#  '17th': 114,
#  'hamlet': 6295,
#  'class': 3017,
#  'denmark': 3961,
#  'nebula': 9840,
#  'herbert': 6506,
#  'masterworks': 8960,
#  'ciencia': 2965,
#  'ficción': 5281,
#  'dune': 4413,
#  'sff': 12673,
#  'work': 15169,
#  'psych': 11363,
#  'growth': 6174,
#  'professional': 11285,
#  'leadership': 8162,
#  'behavior': 1691,
#  'entrepreneurship': 4770,
#  'learning': 8170,
#  'communication': 3246,
#  'malcolm': 8778,
#  'gladwell': 5955,
#  'advertising': 646,
#  'marketing': 8896,
#  'human': 6845,
#  'career': 2555,
#  'jobs': 7472,
#  'startup': 13331,
#  'innovation': 7118,
#  'biografias': 1869,
#  'technology': 13839,
#  'paused': 10610,
#  'computers': 3284,
#  'biografie': 1870,
#  'apple': 1085,
#  'steve': 13375,
#  'tech': 13831,
#  'ibooks': 6908,
#  'design': 3995,
#  'people': 10683,
#  'hemingway': 6493,
#  'fishing': 5388,
#  'ernest': 4838,
#  'cuba': 3672,
#  'laureates': 8129,
#  'sea': 12520,
#  'faith': 5080,
#  'heaven': 6455,
#  'feel': 5218,
#  'gables': 5710,
#  'orphans': 10359,
#  'montgomery': 9507,
#  'nephilim': 9881,
#  'fairies': 5070,
#  'fae': 5062,
#  'louisiana': 8569,
#  'rebecca': 11687,
#  'wells': 14952,
#  '2002': 238,
#  'highlander': 6571,
#  'outlander': 10395,
#  'diana': 4066,
#  'gabaldon': 5708,
#  'highlanders': 6572,
#  '18th': 137,
#  'scotland': 12493,
#  ...}

# %%
doc = 0
feature_index = tags_matrix[doc,:].nonzero()[1]
tfidf_scores = zip(feature_index, [tags_matrix[doc, x] for x in feature_index])

# %%
books_metadata['tags'][0]
# Out:
# 'books teen-fiction loved adventure suzanne-collins fantasy-sci-fi read-more-than-once owned sci-fi-fantasy science-fiction finished-series hunger-games read-2012 default dystopian-fiction read-in-2014 ebook novel favorite-books audiobooks fiction ya-fantasy futuristic series favs favourites own-it love-triangle survival re-read my-books to-read the-hunger-games scifi-fantasy thriller favorite-series my-favorites reviewed ya-fiction borrowed young-adult i-own action-adventure novels audiobook kindle 2012-reads completed-series e-book coming-of-age sci-fi trilogy dystopian distopian read-in-2011 read-in-2013 favourite-books suspense ya-dystopian scifi audio young-adult-fiction love ya-books teen favorites to-buy dystopia read-2011 my-library book-club contemporary post-apocalyptic sf ya all-time-favorites dystopias ebooks shelfari-favorites favorite 5-star favourite read-in-2012 reread books-i-own library currently-reading speculative-fiction faves action distopia ya-lit future english drama read-in-2010 5-stars romance finished fantasy'

# %%
feature_names = tfidf.get_feature_names_out()
tfidf_scores_sorted=[]
for w, s in [(feature_names[i], s) for (i, s) in tfidf_scores]:
    tfidf_scores_sorted.append([w,s])
    print(w,s)
tfidf_scores_sorted
# Out:
# romance 0.04199622977855118
# stars 0.044902535151457965
# 2010 0.06125957409048316
# drama 0.0493160446958989
# english 0.04271333194149995
# future 0.1014833466079337
# lit 0.03843695526480429
# distopia 0.12415576195547642
# faves 0.07285947769502386
# speculative 0.07251109380641134
# reading 0.022981255535489718
# currently 0.02323081081003255
# reread 0.06447599331006632
# star 0.07502456600504018
# shelfari 0.04540261740206127
# ebooks 0.03006444297235562
# dystopias 0.11595489846127825
# time 0.048117547849799436
# sf 0.07317137596247389
# apocalyptic 0.0941436201663041
# post 0.09032041817820312
# contemporary 0.03622900456869731
# club 0.0409993795173276
# library 0.04656396799540881
# dystopia 0.08248694113279853
# buy 0.025624979389037794
# audio 0.03151942701504474
# suspense 0.05403790104772188
# favourite 0.1560120654896369
# 2013 0.039226482136424316
# 2011 0.10322233000148888
# distopian 0.12208063904468137
# trilogy 0.09256582324936077
# age 0.06718730323616848
# coming 0.06839317342500893
# book 0.050751852706958665
# completed 0.089575556902867
# reads 0.03774426537881872
# kindle 0.026711632359192234
# audiobook 0.03004248127804336
# novels 0.03321781659626496
# action 0.11140526633957135
# adult 0.05027430700208993
# young 0.08955243313353396
# borrowed 0.045322598070719824
# reviewed 0.05507105440152741
# favorites 0.09132035307515732
# thriller 0.05271544200062029
# scifi 0.11833114913195371
# survival 0.09227270649072086
# triangle 0.09451559019735938
# love 0.11821827337892689
# favourites 0.032486803170974646
# favs 0.08061050008143492
# futuristic 0.1022233545057037
# ya 0.3015041597733735
# audiobooks 0.03126650413350008
# favorite 0.10421703627009951
# novel 0.04076188141812141
# ebook 0.0275530194422378
# 2014 0.03643997356463908
# dystopian 0.2438659408990413
# default 0.027116021505186452
# 2012 0.13188945761251694
# games 0.2870704991769456
# hunger 0.3549431989239167
# series 0.15108275939587953
# finished 0.09326301234683843
# science 0.04945565646920866
# owned 0.02282780557435825
# read 0.22716233611785352
# fi 0.1495941030863451
# sci 0.14867724045144692
# fantasy 0.20939881583030973
# collins 0.1627826657237944
# suzanne 0.16895997553164158
# adventure 0.0904612339496559
# loved 0.08211145764823509
# fiction 0.15910906255198426
# teen 0.121055818234319
# books 0.1362974016707121
# [['romance', 0.04199622977855118],
#  ['stars', 0.044902535151457965],
#  ['2010', 0.06125957409048316],
#  ['drama', 0.0493160446958989],
#  ['english', 0.04271333194149995],
#  ['future', 0.1014833466079337],
#  ['lit', 0.03843695526480429],
#  ['distopia', 0.12415576195547642],
#  ['faves', 0.07285947769502386],
#  ['speculative', 0.07251109380641134],
#  ['reading', 0.022981255535489718],
#  ['currently', 0.02323081081003255],
#  ['reread', 0.06447599331006632],
#  ['star', 0.07502456600504018],
#  ['shelfari', 0.04540261740206127],
#  ['ebooks', 0.03006444297235562],
#  ['dystopias', 0.11595489846127825],
#  ['time', 0.048117547849799436],
#  ['sf', 0.07317137596247389],
#  ['apocalyptic', 0.0941436201663041],
#  ['post', 0.09032041817820312],
#  ['contemporary', 0.03622900456869731],
#  ['club', 0.0409993795173276],
#  ['library', 0.04656396799540881],
#  ['dystopia', 0.08248694113279853],
#  ['buy', 0.025624979389037794],
#  ['audio', 0.03151942701504474],
#  ['suspense', 0.05403790104772188],
#  ['favourite', 0.1560120654896369],
#  ['2013', 0.039226482136424316],
#  ['2011', 0.10322233000148888],
#  ['distopian', 0.12208063904468137],
#  ['trilogy', 0.09256582324936077],
#  ['age', 0.06718730323616848],
#  ['coming', 0.06839317342500893],
#  ['book', 0.050751852706958665],
#  ['completed', 0.089575556902867],
#  ['reads', 0.03774426537881872],
#  ['kindle', 0.026711632359192234],
#  ['audiobook', 0.03004248127804336],
#  ['novels', 0.03321781659626496],
#  ['action', 0.11140526633957135],
#  ['adult', 0.05027430700208993],
#  ['young', 0.08955243313353396],
#  ['borrowed', 0.045322598070719824],
#  ['reviewed', 0.05507105440152741],
#  ['favorites', 0.09132035307515732],
#  ['thriller', 0.05271544200062029],
#  ['scifi', 0.11833114913195371],
#  ['survival', 0.09227270649072086],
#  ['triangle', 0.09451559019735938],
#  ['love', 0.11821827337892689],
#  ['favourites', 0.032486803170974646],
#  ['favs', 0.08061050008143492],
#  ['futuristic', 0.1022233545057037],
#  ['ya', 0.3015041597733735],
#  ['audiobooks', 0.03126650413350008],
#  ['favorite', 0.10421703627009951],
#  ['novel', 0.04076188141812141],
#  ['ebook', 0.0275530194422378],
#  ['2014', 0.03643997356463908],
#  ['dystopian', 0.2438659408990413],
#  ['default', 0.027116021505186452],
#  ['2012', 0.13188945761251694],
#  ['games', 0.2870704991769456],
#  ['hunger', 0.3549431989239167],
#  ['series', 0.15108275939587953],
#  ['finished', 0.09326301234683843],
#  ['science', 0.04945565646920866],
#  ['owned', 0.02282780557435825],
#  ['read', 0.22716233611785352],
#  ['fi', 0.1495941030863451],
#  ['sci', 0.14867724045144692],
#  ['fantasy', 0.20939881583030973],
#  ['collins', 0.1627826657237944],
#  ['suzanne', 0.16895997553164158],
#  ['adventure', 0.0904612339496559],
#  ['loved', 0.08211145764823509],
#  ['fiction', 0.15910906255198426],
#  ['teen', 0.121055818234319],
#  ['books', 0.1362974016707121]]

# %%
tfidf_scores_sorted_df=pd.DataFrame(tfidf_scores_sorted)
tfidf_scores_sorted_df.columns=['token','val']
tfidf_scores_sorted_df.sort_values(by='val',ascending=False,inplace=True)
tfidf_scores_sorted_df.head(20)
# Out:
#         token       val
# 65     hunger  0.354943
# 55         ya  0.301504
# 64      games  0.287070
# 61  dystopian  0.243866
# 70       read  0.227162
# 73    fantasy  0.209399
# 75    suzanne  0.168960
# 74    collins  0.162783
# 78    fiction  0.159109
# 28  favourite  0.156012
# 66     series  0.151083
# 71         fi  0.149594
# 72        sci  0.148677
# 80      books  0.136297
# 63       2012  0.131889
# 7    distopia  0.124156
# 31  distopian  0.122081
# 79       teen  0.121056
# 48      scifi  0.118331
# 51       love  0.118218

# %% [markdown]
# ¿Que palabras comunes se les ocurre que podríamos sacar?

# %% [markdown]
# ### Similitud Coseno

# %% [markdown]
# <img src="similitud_coseno.jpg" align="center" width="60%"/>

# %% [markdown]
# La imagen muestra la similitud coseno en dos dimensiones. Si dos vectores de datos son cercanos, el ángulo entre estos dos vectores es pequeño y la similitud coseno será alta. En el extremo, dos vectores iguales tendrán un ángulo de 0 grados, un coseno de 1, y una similitud coseno también de 1.
#
# Naturalmente, podemos llevar el concepto para N dimensiones.

# %%
similarity_matrix = cosine_similarity(tags_matrix,tags_matrix)
similarity_matrix
# Out:
# array([[1.        , 0.38961343, 0.40894373, ..., 0.09091467, 0.16148787,
#         0.03602845],
#        [0.38961343, 1.        , 0.37207812, ..., 0.0886315 , 0.16692497,
#         0.04592596],
#        [0.40894373, 0.37207812, 1.        , ..., 0.05919159, 0.09024158,
#         0.02882952],
#        ...,
#        [0.09091467, 0.0886315 , 0.05919159, ..., 1.        , 0.05409486,
#         0.12427748],
#        [0.16148787, 0.16692497, 0.09024158, ..., 0.05409486, 1.        ,
#         0.11579571],
#        [0.03602845, 0.04592596, 0.02882952, ..., 0.12427748, 0.11579571,
#         1.        ]])

# %%
def recommend_books_based_on_plot(book_input,n=15):
    book_index = books_metadata.loc[books_metadata.original_title==book_input,:].index[0]

    #get similarity values with other books
    #similarity_score is the list of index and similarity matrix
    similarity_score = list(enumerate(similarity_matrix[book_index]))

    #sort in descending order the similarity score of book inputted with all the other books
    similarity_score = sorted(similarity_score, key=lambda x: x[1], reverse=True)

    # Get the scores of the 15 most similar books. Ignore the first book.
    similarity_score = similarity_score[1:n]

    #return book names using the mapping series
    book_indices = [i[0] for i in similarity_score]

    return (books_metadata[['original_title','authors','tags']].iloc[book_indices])

# %%
recommend_books_based_on_plot('Nineteen Eighty-Four',10)
# Out:
#                                 original_title  \
# 54                             Brave New World
# 13                  Animal Farm: A Fairy Story
# 47                              Fahrenheit 451
# 27                          Lord of the Flies
# 70     Frankenstein; or, The Modern Prometheus
# 172                         A Clockwork Orange
# 808  Brave New World/Brave New World Revisited
# 7                       The Catcher in the Rye
# 845                         Animal Farm & 1984
#
#                                                authors  \
# 54                                       Aldous Huxley
# 13                                       George Orwell
# 47                                        Ray Bradbury
# 27                                     William Golding
# 70   Mary Wollstonecraft Shelley, Percy Bysshe Shel...
# 172                                    Anthony Burgess
# 808                Aldous Huxley, Christopher Hitchens
# 7                                        J.D. Salinger
# 845                George Orwell, Christopher Hitchens
#
#                                                   tags
# 54   books read-for-school 1001-books general-ficti...
# 13   books read-for-school 1001-books allegory gene...
# 47   books read-for-school general-fiction school f...
# 27   books read-for-school 1001-books adventure gen...
# 70   books 19th-century read-for-school 1001-books ...
# 172  books rory-gilmore-reading-list movies england...
# 808  books read-for-school 1001-books general-ficti...
# 7    books read-for-school 1001-books general-ficti...
# 845  books read-for-school allegory general-fiction...

# %%
recommend_books_based_on_plot('Nineteen Eighty-Four',15)
# Out:
#                                         original_title  \
# 54                                     Brave New World
# 13                          Animal Farm: A Fairy Story
# 47                                      Fahrenheit 451
# 27                                  Lord of the Flies
# 70             Frankenstein; or, The Modern Prometheus
# 172                                 A Clockwork Orange
# 808          Brave New World/Brave New World Revisited
# 7                               The Catcher in the Rye
# 845                                 Animal Farm & 1984
# 64   Slaughterhouse-Five, or The Children's Crusade...
# 94                          The Picture of Dorian Gray
# 4                                     The Great Gatsby
# 159                                 Great Expectations
# 128                    One Flew Over the Cuckoo's Nest
#
#                                                authors  \
# 54                                       Aldous Huxley
# 13                                       George Orwell
# 47                                        Ray Bradbury
# 27                                     William Golding
# 70   Mary Wollstonecraft Shelley, Percy Bysshe Shel...
# 172                                    Anthony Burgess
# 808                Aldous Huxley, Christopher Hitchens
# 7                                        J.D. Salinger
# 845                George Orwell, Christopher Hitchens
# 64                                   Kurt Vonnegut Jr.
# 94                      Oscar Wilde, Jeffrey Eugenides
# 4                                  F. Scott Fitzgerald
# 159                                    Charles Dickens
# 128                                          Ken Kesey
#
#                                                   tags
# 54   books read-for-school 1001-books general-ficti...
# 13   books read-for-school 1001-books allegory gene...
# 47   books read-for-school general-fiction school f...
# 27   books read-for-school 1001-books adventure gen...
# 70   books 19th-century read-for-school 1001-books ...
# 172  books rory-gilmore-reading-list movies england...
# 808  books read-for-school 1001-books general-ficti...
# 7    books read-for-school 1001-books general-ficti...
# 845  books read-for-school allegory general-fiction...
# 64   books read-for-school aliens 1001-books postmo...
# 94   books 19th-century read-for-school 1001-books ...
# 4    books read-for-school 1001-books general-ficti...
# 159  books 19th-century read-for-school 1001-books ...
# 128  books books-to-buy rory-gilmore-reading-list m...

# %%
recommend_books_based_on_plot('Misery')
# Out:
#              original_title                                authors  \
# 910           Gerald's Game                           Stephen King
# 1074      Dolores Claiborne           Stephen King, Dominique Dill
# 674             Firestarter                           Stephen King
# 304            Pet Sematary                           Stephen King
# 669           The Dead Zone                           Stephen King
# 6322                    NaN                           Stephen King
# 552          Needful Things                           Stephen King
# 1422            Rose Madder                           Stephen King
# 914                Insomnia  Stephen King, Bettina Blanch Tyroller
# 704                 Thinner          Richard Bachman, Stephen King
# 348             Salem's Lot                           Stephen King
# 3204  Cycle of the Werewolf         Stephen King, Bernie Wrightson
# 966           The Dark Half                           Stephen King
# 1338               The Mist                           Stephen King
#
#                                                    tags
# 910   psychological-thriller books couldn-t-finish c...
# 1074  psychological-thriller books calibre general-f...
# 674   books adventure calibre general-fiction suspen...
# 304   books movies general-fiction contemporary-fict...
# 669   books calibre general-fiction fantasy-sci-fi s...
# 6322  books listened-to movies general-fiction conte...
# 552   books calibre general-fiction fantasy-sci-fi s...
# 1422  books calibre general-fiction contemporary-fic...
# 914   books calibre general-fiction contemporary-fic...
# 704   books calibre general-fiction prose stand-alon...
# 348   books general-fiction contemporary-fiction sta...
# 3204  books calibre general-fiction stand-alone shap...
# 966   books calibre general-fiction movie suspense-t...
# 1338  books movies read-2016 england calibre stand-a...

# %%
recommend_books_based_on_plot('The Hobbit')
# Out:
#                                      original_title  \
# 3520                       Neverwhere Graphic Novel
# 963            The Hobbit and The Lord of the Rings
# 154                                  The Two Towers
# 18                       The Fellowship of the Ring
# 7421                                       Coraline
# 6                The Hobbit or There and Back Again
# 160                          The Return of the King
# 8373                            Darth Vader and Son
# 6737                               The Hedge Knight
# 1697            The Dark Tower: The Gunslinger Born
# 610                                The Silmarillion
# 188                           The Lord of the Rings
# 8382           A Wrinkle in Time: The Graphic Novel
# 3634  Bone: The Complete Cartoon Epic in One Volume
#
#                                                 authors  \
# 3520               Mike Carey, Glenn Fabry, Neil Gaiman
# 963                                      J.R.R. Tolkien
# 154                                      J.R.R. Tolkien
# 18                                       J.R.R. Tolkien
# 7421                      Neil Gaiman, P. Craig Russell
# 6                                        J.R.R. Tolkien
# 160                                      J.R.R. Tolkien
# 8373                                      Jeffrey Brown
# 6737      Ben Avery, Mike S. Miller, George R.R. Martin
# 1697  Peter David, Robin Furth, Jae Lee, Richard Isa...
# 610    J.R.R. Tolkien, Christopher Tolkien, Ted Nasmith
# 188                                      J.R.R. Tolkien
# 8382                     Hope Larson, Madeleine L'Engle
# 3634                                         Jeff Smith
#
#                                                    tags
# 3520  england adventure fantasy-sci-fi urban comic-b...
# 963   books hobbit loved movies adventure fantasy-sc...
# 154   books movies 1001-books adventure fantasy-sci-...
# 18    books movies 1001-books adventure lotr movie r...
# 7421  books teen-fiction movies england adventure re...
# 6     books read-for-school 1001-books adventure sch...
# 160   books movies 1001-books adventure fantasy-sci-...
# 8373  read-2016 quadrinhos funny read-2014 childrens...
# 6737  books read-2016 2015-reads adventure male-auth...
# 1697  books adventure comix marvel fantasy-sci-fi co...
# 610   books adventure fantasy-sci-fi lotr read-more-...
# 188   books movies 1001-books adventure fantasy-sci-...
# 8382  read-2016 adventure childrens-books fantasy-sc...
# 3634  books adventure comix funny favorite-comics bo...

# %% [markdown]
# Para obtener recomendaciones más diversas, podríamos dejar afuera las novelas del mismo autor de la novela target.

# %% [markdown]
# ## Filtros colaborativos: Librería Surprise

# %% [markdown]
# Tenemos que crear un objeto dataset para trabajar con Surprise. Este dataset contiene los siguientes elementos:
# 1. Los IDs de los usuarios
# 2. Los IDs de cada ítem (en este caso, de cada libro)
# 3. El rating correspondiente (en este caso, en una escala del 1 al 5)

# %%
from surprise import Dataset, Reader

reader = Reader(rating_scale=(1, 5))
data = Dataset.load_from_df(ratings_data[['user_id', 'book_id', 'rating']], reader)

# %% [markdown]
# ### Entrenamos un modelo SVD con crossvalidation

# %% [markdown]
# Podemos entrenar con cross-validation un modelo que realiza SVD (descomposición de valor singular o Singular Value Decomposition) para construir un sistema de recomendación. SVD es un algoritmo de factorización de matrices que puede utilizarse para sistemas de recomendación.
#
# Los sistemas de recomendación que utilizan la factorización matricial suelen seguir un patrón en el que una matriz de puntuaciones se factoriza en un producto de matrices que representan factores latentes para los ítems (en este caso, libros) y los usuarios. Funciona con la técnica de factorización matricial que vimos la clase pasada.

# %%
from surprise import SVD
from surprise.model_selection import cross_validate

svd = SVD(verbose=True, n_epochs=10)
cross_validate(svd, data, measures=['RMSE', 'MAE'], cv=3, verbose=True)
# Out:
# Processing epoch 0
# Processing epoch 1
# Processing epoch 2
# Processing epoch 3
# Processing epoch 4
# Processing epoch 5
# Processing epoch 6
# Processing epoch 7
# Processing epoch 8
# Processing epoch 9
# Processing epoch 0
# Processing epoch 1
# Processing epoch 2
# Processing epoch 3
# Processing epoch 4
# Processing epoch 5
# Processing epoch 6
# Processing epoch 7
# Processing epoch 8
# Processing epoch 9
# Processing epoch 0
# Processing epoch 1
# Processing epoch 2
# Processing epoch 3
# Processing epoch 4
# Processing epoch 5
# Processing epoch 6
# Processing epoch 7
# Processing epoch 8
# Processing epoch 9
# Evaluating RMSE, MAE of algorithm SVD on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    0.8562  0.8552  0.8573  0.8562  0.0009
# MAE (testset)     0.6759  0.6751  0.6755  0.6755  0.0003
# Fit time          3.50    4.00    4.09    3.86    0.26
# Test time         2.14    2.19    2.26    2.20    0.05
# {'test_rmse': array([0.85621786, 0.85521367, 0.85730108]),
#  'test_mae': array([0.67586187, 0.67507524, 0.67550073]),
#  'fit_time': (3.4980738162994385, 3.996868133544922, 4.0857460498809814),
#  'test_time': (2.1360020637512207, 2.18822979927063, 2.262756824493408)}

# %% [markdown]
# También podemos entrenar el modelo en todo el conjunto de datos utilizando el método fit después de convertir el objeto Dataset en un objeto Surprise Trainset utilizando el método build_full_trainset.

# %%
trainset = data.build_full_trainset()
svd.fit(trainset)
# Out:
# Processing epoch 0
# Processing epoch 1
# Processing epoch 2
# Processing epoch 3
# Processing epoch 4
# Processing epoch 5
# Processing epoch 6
# Processing epoch 7
# Processing epoch 8
# Processing epoch 9

# %% [markdown]
# Ahora podemos realizar predicciones para un ID de un libro específico, con el método predict.

# %%
svd.predict(uid=10, iid=100)
# Out:
# Prediction(uid=10, iid=100, r_ui=None, est=3.902505952678895, details={'was_impossible': False})

# %% [markdown]
# Tomemos de ejemplo un fanático confeso de los libros de Dan Brown (autor de El Código Da Vinci). Observemos sus puntuaciones a los libros de dicho autor:

# %%
books_metadata.loc[books_metadata.authors.str.contains('Dan Brown'),:]
# Out:
#         id   book_id  best_book_id   work_id  books_count        isbn  \
# 8        9       960           960   3338963          311  1416524797
# 25      26       968           968   2982101          350   307277674
# 144    145       976           976   3135896          180   671027387
# 169    170     11125         11125     40195          185   552151696
# 200    201   6411961       6411961   6600281          208   385504225
# 239    240  17212231      17212231  23841765          235   385537859
# 4495  4496    643301        643301  24585562            6   593054601
#
#             isbn13    authors  original_publication_year     original_title  \
# 8     9.781417e+12  Dan Brown                     2000.0   Angels & Demons
# 25    9.780307e+12  Dan Brown                     2003.0  The Da Vinci Code
# 144   9.780671e+12  Dan Brown                     2001.0    Deception Point
# 169   9.780552e+12  Dan Brown                     1998.0   Digital Fortress
# 200   9.780386e+12  Dan Brown                     2009.0    The Lost Symbol
# 239   9.780386e+12  Dan Brown                     2013.0            Inferno
# 4495  9.780593e+12  Dan Brown                     2003.0                NaN
#
#       ... work_ratings_count work_text_reviews_count  ratings_1  ratings_2  \
# 8     ...            2078754                   25112      77841     145740
# 25    ...            1557292                   41560      71345     126493
# 144   ...             479733                    7798      14380      45006
# 169   ...             447503                    7538      16592      47507
# 200   ...             404982                   24199      11293      40545
# 239   ...             345560                   33700       7261      26077
# 4495  ...              18765                     476        254        636
#
#       ratings_3  ratings_4  ratings_5  \
# 8        458429     716569     680175
# 25       340790     539277     479387
# 144      143182     160819     116346
# 169      136196     144029     103179
# 200      120122     136545      96477
# 239       89237     128374      94611
# 4495       2797       6648       8430
#
#                                               image_url  \
# 8     https://images.gr-assets.com/books/1303390735m...
# 25    https://images.gr-assets.com/books/1303252999m...
# 144   https://s.gr-assets.com/assets/nophoto/book/11...
# 169   https://images.gr-assets.com/books/1360095966m...
# 200   https://images.gr-assets.com/books/1358274396m...
# 239   https://images.gr-assets.com/books/1397093185m...
# 4495  https://s.gr-assets.com/assets/nophoto/book/11...
#
#                                         small_image_url  \
# 8     https://images.gr-assets.com/books/1303390735s...
# 25    https://images.gr-assets.com/books/1303252999s...
# 144   https://s.gr-assets.com/assets/nophoto/book/50...
# 169   https://images.gr-assets.com/books/1360095966s...
# 200   https://images.gr-assets.com/books/1358274396s...
# 239   https://images.gr-assets.com/books/1397093185s...
# 4495  https://s.gr-assets.com/assets/nophoto/book/50...
#
#                                                    tags
# 8     books murder-mystery movies adventure general-...
# 25    books movies adventure general-fiction mystery...
# 144   books adventure general-fiction mystery-crime ...
# 169   books adventure general-fiction mystery-crime ...
# 200   books adventure general-fiction mystery-crime ...
# 239   books books-read-in-2013 read-2016 adventure g...
# 4495  books adventure religion before-2008 contempor...
#
# [7 rows x 24 columns]

# %%
libros_db=books_metadata.loc[books_metadata.authors.str.contains('Dan Brown'),'id'].values
libros_db
# Out:
# array([   9,   26,  145,  170,  201,  240, 4496])

# %%
libros_leidos_usuario_db=ratings_data.loc[(ratings_data.user_id==18313)&(ratings_data.book_id.isin(libros_db)),:]
libros_leidos_usuario_db
# Out:
#       book_id  user_id  rating
# 843         9    18313       5
# 2539       26    18313       5

# %% [markdown]
# Vemos que en general hace una muy buena evaluación de los libros de DB

# %%
libros_db[~np.isin(libros_db,libros_leidos_usuario_db)]
# Out:
# array([ 145,  170,  201,  240, 4496])

# %%
pendientes_db=libros_db[~np.isin(libros_db,libros_leidos_usuario_db)]
pred=[]
for libro in pendientes_db:
    pred.append(svd.predict(uid=18313, iid=libro).est)

media_db=ratings_data.loc[ratings_data.book_id.isin(libros_db),"rating"].mean()    
print(f'Media ratings libros DB: {media_db}')    
print(f'Media ratings puntuación estimada libros no leídos de DB por usuario 18313: {np.array(pred).mean()}')
# Out:
# Media ratings libros DB: 3.437410071942446
# Media ratings puntuación estimada libros no leídos de DB por usuario 18313: 3.51842192050196

# %% [markdown]
# Vemos que la puntuación promedio estimada por nuestro modelo para los libros aún no leídos de Dan Brown es superior al promedio.

# %% [markdown]
# ### Generando recomendaciones

# %%
import difflib
import random

def get_book_id(book_title, metadata):
    
    existing_titles = list(metadata['title'].values)
    closest_titles = difflib.get_close_matches(book_title, existing_titles)
    book_id = metadata[metadata['title'] == closest_titles[0]]['id'].values[0]
    return book_id

def get_book_info(book_id, metadata):
    
    book_info = metadata[metadata['id'] == book_id][['id', 'isbn', 
                                                    'authors', 'title', 'original_title']]
    return book_info.to_dict(orient='records')

def predict_review(user_id, book_title, model, metadata):
    
    book_id = get_book_id(book_title, metadata)
    review_prediction = model.predict(uid=user_id, iid=book_id)
    return review_prediction.est

def generate_recommendation(user_id, model, metadata, thresh=4):
    
    book_titles = list(metadata['title'].values)
    random.shuffle(book_titles)
    
    for book_title in book_titles:
        rating = predict_review(user_id, book_title, model, metadata)
        if rating >= thresh:
            book_id = get_book_id(book_title, metadata)
            return get_book_info(book_id, metadata)

# %% [markdown]
# La función generate_recommendation genera una recomendación de libros para un usuario iterando a través de la lista de títulos de libros y prediciendo las valoraciones de los usuarios para cada título hasta que encuentra un libro con una valoración igual o superior al umbral especificado que lo califica para ser recomendado a un usuario.

# %%
generate_recommendation(18313, svd, books_metadata, 4)
# Out:
# [{'id': 8286,
#   'isbn': '684800012',
#   'authors': 'Harold McGee',
#   'title': 'On Food and Cooking: The Science and Lore of the Kitchen',
#   'original_title': 'On Food and Cooking: The Science and Lore of the Kitchen'}]

# %% [markdown]
# ### Visualizando las similitudes entre los libros utilizando t-SNE

# %%
svd.qi.shape
# Out:
# (10000, 100)

# %% [markdown]
# Ahora podemos apreciar la similitud entre los libros a partir de la matriz de factorización resultante luego de aplicar el algoritmo SVD.
#
# Esta matriz de 10.000 x 100 tiene un vector de 100 dimensiones para cada libro, que son demasiadas dimensiones para que podamos visualizarlas intuitivamente, pero podemos utilizar una técnica de reducción de la dimensionalidad para representar cada libro como un punto bidimensional en el espacio.
#
# Podemos utilizar t-SNE (t-Distributed Stochastic Neighbors Embedding, una alternativa a PCA) para representar cada libro como un punto bidimensional.

# %%
from sklearn.manifold import TSNE

tsne = TSNE(n_components=2, n_iter=500, verbose=3, random_state=1)
books_embedding = tsne.fit_transform(svd.qi)
projection = pd.DataFrame(columns=['x', 'y'], data=books_embedding)
projection['title'] = books_metadata['original_title']

# %%
import plotly.express as px

fig = px.scatter(
    projection, x='x', y='y'
)
fig.show()

report = dp.Report(dp.Plot(fig) ) #Create a report
# report.publish(name='books_scatter_plot', open=True, visibility='PUBLIC') #Publish the report

# %% [markdown]
# Podemos ver que los puntos que representan los 10.000 libros parecen seguir una distribución normal bidimensional. Podemos explicar esta distribución de la siguiente forma:
#
# - Algunos libros pueden ser populares en general entre un amplio abanico de audiencias y, por tanto, corresponder a puntos en el centro de este diagrama de dispersión.
# - Otros libros pueden pertenecer a géneros muy específicos, como las novelas de vampiros, de misterio o románticas, que son populares entre un público concreto. Estos libros pueden corresponder a puntos alejados del centro del diagrama.

# %%
import datapane as dp

def plot_books(titles, plot_name):
    
    book_indices = []
    for book in titles:
        book_indices.append(get_book_id(book, books_metadata)-1)
        
    book_vector_df = projection.iloc[book_indices]
    
    fig = px.scatter(
    book_vector_df, x='x', y='y', text='title',
    )
    fig.show()
    
    report = dp.Report(dp.Plot(fig) ) #Create a report
#     report.publish(name=plot_name, open=True, visibility='PUBLIC') #Publish the report

# %% [markdown]
# ¿Qué pasa si observamos algunos libros específicos? ¿Su similitud de características se ve reflejada en el nuevo espacio de dimensiones?

# %%
books = list(books_metadata['title'][:30])
plot_books(books, plot_name='books_embedding')

# %%
from collections import defaultdict

from surprise import Dataset, SVD


def get_top_n(predictions, n=10):
    """Return the top-N recommendation for each user from a set of predictions.

    Args:
        predictions(list of Prediction objects): The list of predictions, as
            returned by the test method of an algorithm.
        n(int): The number of recommendation to output for each user. Default
            is 10.

    Returns:
    A dict where keys are user (raw) ids and values are lists of tuples:
        [(raw item id, rating estimation), ...] of size n.
    """

    # First map the predictions to each user.
    top_n = defaultdict(list)
    for uid, iid, true_r, est, _ in predictions:
        top_n[uid].append((iid, est))

    # Then sort the predictions for each user and retrieve the k highest ones.
    for uid, user_ratings in top_n.items():
        user_ratings.sort(key=lambda x: x[1], reverse=True)
        top_n[uid] = user_ratings[:n]

    return top_n

algo = SVD()
algo.fit(trainset)

# %%
# Predice los ratings para todo par (u, i) que no aparece en train
# testset = trainset.build_anti_testset()
# predictions = algo_baseline.test(testset)

# Recomendamos usar un subsample porque las combinaciones de libros/usuarios que no aparecen en el set de
# train es muy grande!

# %%
libros_leidos_usuario=ratings_data.loc[(ratings_data.user_id==18313),'book_id']
libros_no_leidos_usuario=ratings_data.loc[~ratings_data.book_id.isin(libros_leidos_usuario),'book_id'].unique()

pred=[]
for libro in libros_no_leidos_usuario:
    pred.append(svd.predict(uid=18313, iid=libro))

# %%
top_n = get_top_n(pred, n=10)
top_n
# Out:
# defaultdict(list,
#             {18313: [(307, 5),
#               (3753, 5),
#               (4868, 5),
#               (5207, 5),
#               (9842, 4.986308263266028),
#               (3628, 4.928676164700801),
#               (3660, 4.906307765193705),
#               (7831, 4.876989856940389),
#               (9569, 4.874730176126109),
#               (4778, 4.859533981643138)]})

# %%
# Predecimos el TOP-10 de recomendaciones para el usuario 18313
for uid, user_ratings in top_n.items():
    print([books_metadata.loc[books_metadata.id==iid,'original_title'].values[0] for (iid, _) in user_ratings])

#En el TOP 10 de libros recomendados para nuestro usuario de prueba, vemos libros de ciencia ficción, religión y misterios,
#lo cual guarda sentido con su gusto con los libros de Dan Brown
# Out:
# ["The Wise Man's Fear", 'Harry Potter Collection (Harry Potter, #1-6)', 'Jesus the Christ: A Study of the Messiah and His Mission according to Holy Scriptures both Ancient and Modern', 'The Days Are Just Packed: A Calvin and Hobbes Collection', 'Humans of New York: Stories', 'The Complete Calvin and Hobbes', 'The Sandman: The Wake', 'رباعيات صلاح جاهين', 'The Hate U Give', 'Holy Bible English Standard Version']

# %% [markdown]
# ### Comparamos el desempeño de varios algoritmos

# %%
ratings_data_f=ratings_data.sample(n=100000)

# %%
#CUIDADO! Mejor utilizar el método train_test_split de SK Learn, y luego convertir el conjunto de datos resultante al objeto Dataset
train, test = skl_train_test_split(ratings_data_f, test_size=0.20,random_state=100)
reader = Reader(rating_scale=(1, 5))
data_train = Dataset.load_from_df(train, reader)

algo_svd = SVD()
algo_knn = KNNBasic()
algo_random=NormalPredictor()
algo_baseline=BaselineOnly()
algo_nmf=NMF()

# %%
cv_random=cross_validate(algo_random, data_train, measures=['RMSE'],cv=4, verbose=False, n_jobs=-1)

# %%
cv_baseline=cross_validate(algo_baseline, data_train, measures=['RMSE'],cv=4, verbose=False, n_jobs=-1)
cv_svd=cross_validate(algo_svd, data_train, measures=['RMSE'],cv=4, verbose=False, n_jobs=-1)
cv_knn=cross_validate(algo_knn, data_train, measures=['RMSE'],cv=4, verbose=False, n_jobs=-1)
cv_nmf=cross_validate(algo_nmf, data_train, measures=['RMSE'],cv=4, verbose=False, n_jobs=-1)

# %%
res=[]
res.append(round(cv_random['test_rmse'].mean(),3))
res.append(round(cv_baseline['test_rmse'].mean(),3))
res.append(round(cv_svd['test_rmse'].mean(),3))
res.append(round(cv_knn['test_rmse'].mean(),3))
res.append(round(cv_nmf['test_rmse'].mean(),3))

res_df=pd.DataFrame(pd.concat([pd.Series(['Random','Baseline','SVD','KNN','NMF']),pd.Series(res)],axis=1))
res_df.columns=['Algoritmo','RMSE CV']
res_df
# Out:
#   Algoritmo  RMSE CV
# 0    Random    1.326
# 1  Baseline    0.932
# 2       SVD    0.934
# 3       KNN    0.991
# 4       NMF    1.112

# %% [markdown]
# Los mejores algoritmos parecen ser el baseline y el SVD.
#
# Ver tiempos de ajuste y rendimiento esperado en https://surpriselib.com/

# %% [markdown]
# ### Métricas específicas de los sistemas de recomendación

# %% [markdown]
# <img src="metricas.png" align="center" width="60%"/>

# %% [markdown]
# Un elemento se considera relevante si su puntuación es superior a un umbral determinado (por ej, mayor o igual a 4). Un elemento se considera recomendado si su puntuación estimada es superior al umbral y se encuentra entre las k mejores puntuaciones estimadas.
#
# Tener en cuenta que en los casos extremos en los que se produce una división por cero, los valores Precision@k y Recall@k no están definidos. Por convención, fijamos sus valores en 0 en estos casos.

# %%
from collections import defaultdict

from surprise import Dataset, SVD
from surprise.model_selection import KFold


def precision_recall_at_k(predictions, k=10, threshold=3.5):
    """Return precision and recall at k metrics for each user"""

    # First map the predictions to each user.
    user_est_true = defaultdict(list)
    for uid, _, true_r, est, _ in predictions:
        user_est_true[uid].append((est, true_r))

    precisions = dict()
    recalls = dict()
    for uid, user_ratings in user_est_true.items():

        # Sort user ratings by estimated value
        user_ratings.sort(key=lambda x: x[0], reverse=True)

        # Number of relevant items
        n_rel = sum((true_r >= threshold) for (_, true_r) in user_ratings)

        # Number of recommended items in top k
        n_rec_k = sum((est >= threshold) for (est, _) in user_ratings[:k])

        # Number of relevant and recommended items in top k
        n_rel_and_rec_k = sum(
            ((true_r >= threshold) and (est >= threshold))
            for (est, true_r) in user_ratings[:k]
        )

        # Precision@K: Proportion of recommended items that are relevant
        # When n_rec_k is 0, Precision is undefined. We here set it to 0.

        precisions[uid] = n_rel_and_rec_k / n_rec_k if n_rec_k != 0 else 0

        # Recall@K: Proportion of relevant items that are recommended
        # When n_rel is 0, Recall is undefined. We here set it to 0.

        recalls[uid] = n_rel_and_rec_k / n_rel if n_rel != 0 else 0

    return precisions, recalls

# %%
kf = KFold(n_splits=4)
# algo = SVD()
precision=[]
recall=[]
for trainset, testset in kf.split(data):
    algo.fit(trainset)
    predictions = algo.test(testset)
    precisions, recalls = precision_recall_at_k(predictions, k=10, threshold=4)

    # Precision and recall can then be averaged over all users
    precision.append(sum(prec for prec in precisions.values()) / len(precisions))
    recall.append(sum(rec for rec in recalls.values()) / len(recalls))

# %%
len(predictions)
# Out:
# 245439

# %%
#Top 5
# print(f'Precision media: {np.array(precision).mean()}')
# print(f'Recall medio: {np.array(recall).mean()}')

# Precision media: 0.49
# Recall medio: 0.34
# Out:
# Precision media: 0.4894720012978624
# Recall medio: 0.34429402285592936

# %%
#Top 10
print(f'Precision media: {np.array(precision).mean()}')
print(f'Recall medio: {np.array(recall).mean()}')

# Precision media: 0.49
# Recall medio: 0.37
# Out:
# Precision media: 0.48574111644278617
# Recall medio: 0.36972470185920686

# %% [markdown]
# Esto significa que, en promedio, el 48% del top 10 de recomendaciones hechas para cada usuario son relevantes (con un puntaje estimado mayor o igual a 4), mientras que de todos los libros relevantes, el 37% aparecieron en el top 10.
#
# Podríamos aumentar k, lo que resultaría en mayor recall a costa de una menor precision. Esto es equivalente a utilizar un punto de corte menor (=menos exigentes) en un modelo convencional de ML.

# %% [markdown]
# # PRÁCTICA
#
# Construir dos sistemas de recomendación:
# - uno basado en contenidos a partir de la columna "overview" (argumento de la película)
# - un modelo basado en filtros colaborativos a partir de los ratings
#
# Además de lo visto en clase, puede ayudarse a partir de lo que aparece acá:
# https://www.datacamp.com/tutorial/recommender-systems-python
#
# El dataset completo está acá: https://www.kaggle.com/datasets/rounakbanik/the-movies-dataset/data
#
# TAREA para el hogar: construir una función para medir precision@k y recall@k a partir del listado de recomendaciones del SR basado en contenidos

# %%
ratings_metadata = pd.read_csv('./data/movies/ratings_small.csv', low_memory=False)
movies_metadata = pd.read_csv('./data/movies/movies_metadata.csv', low_memory=False)

print(ratings_metadata.shape)
ratings_metadata.head()
# Out:
# (100004, 4)
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205

# %%
print(movies_metadata.shape)
movies_metadata.head()
# Out:
# (45466, 24)
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ... release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...   1995-10-30
# 1  When siblings Judy and Peter discover an encha...  ...   1995-12-15
# 2  A family wedding reignites the ancient feud be...  ...   1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...  ...   1995-12-22
# 4  Just when George Banks has recovered from his ...  ...   1995-02-10
#
#        revenue runtime                                   spoken_languages  \
# 0  373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7     5415.0
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
#
# [5 rows x 24 columns]

# %% [markdown]
# ## BIBLIOGRAFÍA
#
# - https://towardsdatascience.com/how-you-can-build-simple-recommender-systems-with-surprise-b0d32a8e4802
# - https://surprise.readthedocs.io/
# - https://medium.com/mlearning-ai/basic-content-based-recommendation-system-with-python-code-be920b412067
# - https://medium.com/analytics-vidhya/content-based-recommender-systems-in-python-2b330e01eb80
# - https://towardsdatascience.com/hands-on-content-based-recommender-system-using-python-1d643bf314e4
#
# LightFM
# - https://towardsdatascience.com/solving-business-usecases-by-recommender-system-using-lightfm-4ba7b3ac8e62
